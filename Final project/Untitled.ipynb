# %%
import os

data_path = "retrosheet_data"
files = os.listdir(data_path)

files[:10]
# Out:
# ['2024PIT.EVN',
#  '2024LAN.EVN',
#  '2024CHN.EVN',
#  '2024HOU.EVA',
#  'WAS2024.ROS',
#  '2024SLN.EVN',
#  'HOU2024.ROS',
#  'MIN2024.ROS',
#  'NYN2024.ROS',
#  'TOR2024.ROS']

# %%
# Read and preview the 2024 Cubs (CHN) event file
file_path = os.path.join(data_path, "2024CHN.EVN")

with open(file_path, "r") as file:
    for _ in range(20):
        print(file.readline().strip())
# Out:
# id,CHN202404010
# version,2
# info,visteam,COL
# info,hometeam,CHN
# info,site,CHI11
# info,date,2024/04/01
# info,number,0
# info,gametype,regular
# info,starttime,1:20PM
# info,daynight,day
# info,innings,9
# info,tiebreaker,2
# info,usedh,true
# info,umphome,may-b901
# info,ump1b,iassd901
# info,ump2b,buckc901
# info,ump3b,ballb901
# info,umplf,(none)
# info,umprf,(none)
# info,inputtime,2024/06/04 06:45:18

# %%
import os

# Get the file size of the Cubs game file
file_path = os.path.join(data_path, "2024CHN.EVN")
file_size_kb = os.path.getsize(file_path) / 1024  # Convert to kilobytes
file_size_kb
# Out:
# 415.66015625

# %%
def get_folder_size(path):
    total = 0
    for dirpath, dirnames, filenames in os.walk(path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            total += os.path.getsize(fp)
    return total / (1024 * 1024)

folder_size_mb = get_folder_size(data_path)
folder_size_mb
# Out:
# 13.054973602294922

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import altair as alt
#       2 import pandas as pd
# ----> 4 df = games_df.copy()
#       6 main_plot = alt.Chart(df).mark_point(size=70, opacity=0.8).encode(
#       7     x=alt.X('attendance:Q', title='Attendance'),
#       8     y=alt.Y('temp:Q', title='Temperature (°F)'),
#    (...)
#      12     title='How Temperature Affects Cubs Game Attendance in 2024'
#      13 ).interactive()
#      15 main_plot.save('plots/main_plot.json')
#
# NameError: name 'games_df' is not defined
